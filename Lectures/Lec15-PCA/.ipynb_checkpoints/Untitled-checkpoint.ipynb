# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

spambase_csv = pd.read_csv('../../Data/spambase.csv')

# %%
spambase_csv.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64             0
# 1            0.21               0.28           0.50             0
# 2            0.06               0.00           0.71             0
# 3            0.00               0.00           0.00             0
# 4            0.00               0.00           0.00             0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail   ...     char_freq_;  char_freq_(  \
# ...

# %%
plt.figure(figsize=(10, 10))

plt.imshow(spambase_csv.corr(), interpolation='none')

# %%
plt.scatter(spambase_csv.word_freq_415, spambase_csv.word_freq_direct)

# %%
# plt.figure(figsize=(10, 10))
# pd.scatter_matrix(spambase_csv)

# %%
fig = plt.figure(figsize=(20, 20))
axes = plt.gca()
axes.scatter(spambase_csv.capital_run_length_average, spambase_csv.capital_run_length_longest, alpha=0.1)
axes.set_xlim(0, 5)
axes.set_ylim(0, 100)
# Out:
# (0, 100)

# %%
from sklearn import datasets

iris = datasets.load_iris()

df = pd.DataFrame(iris.data)
df.columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid']
df.dropna(how="all", inplace=True) # drops the empty line at file-end


pd.scatter_matrix(df, figsize=(10, 10));

# %%
plt.scatter(df.petal_wid, df.petal_len)
from mpl_toolkits.mplot3d import Axes3D

# %%
from sklearn.decomposition import PCA

X = df

pca = PCA()

pca.fit(X)
# Out:
# PCA(copy=True, n_components=None, whiten=False)

# %%
components = pca.components_
pca_score = pca.explained_variance_ratio_

components
# Out:
# array([[ 0.36158968, -0.08226889,  0.85657211,  0.35884393],
#        [-0.65653988, -0.72971237,  0.1757674 ,  0.07470647],
#        [ 0.58099728, -0.59641809, -0.07252408, -0.54906091],
#        [ 0.31725455, -0.32409435, -0.47971899,  0.75112056]])

# %%
pca_score

components.T * pca_score / pca_score.min()
# Out:
# array([[  64.50437278,   -6.71546612,    1.92636595,    0.31725455],
#        [ -14.67603605,   -7.46391625,   -1.97749548,   -0.32409435],
#        [ 152.8048223 ,    1.79784972,   -0.24046224,   -0.47971899],
#        [  64.01455528,    0.76414058,   -1.8204771 ,    0.75112056]])

# %%
x1_pca_axis, x2_pca_axis, x3_pca_axis, x4_pca_axis = 3 * components.T

# %%
plt.clf()

plt.scatter(x1_pca_axis, x2_pca_axis)
plt.scatter(x1_pca_axis, x3_pca_axis)
plt.scatter(x1_pca_axis, x4_pca_axis)
plt.scatter(x2_pca_axis, x3_pca_axis)
plt.scatter(x2_pca_axis, x4_pca_axis)
plt.scatter(x3_pca_axis, x4_pca_axis)

# %%
# explained_variance = pca.explained_variance_

# np.cumsum

# %%
lemons = pd.read_csv('../../Data/lemon_training.csv')

# %%
len(lemons)
# Out:
# 51088
