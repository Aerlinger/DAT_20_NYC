# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
titanic_csv = pd.read_csv('../../Data/titanic.csv')

print titanic_csv.columns
# Out:
# Index([u'survived', u'pclass', u'name', u'sex', u'age', u'sibsp', u'parch', u'ticket', u'fare', u'cabin', u'embarked'], dtype='object')

# %%
print titanic_csv.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex  age  sibsp  parch            ticket     fare cabin embarked
# 0    male   22      1      0         A/5 21171   7.2500   NaN        S
# 1  female   38      1      0          PC 17599  71.2833   C85        C
# 2  female   26      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female   35      1      0            113803  53.1000  C123        S
# 4    male   35      0      0            373450   8.0500   NaN        S

# %%
titanic = titanic_csv.drop(['name', 'embarked', 'cabin', 'ticket', 'sibsp', 'parch'], axis=1)

# %%
titanic['female']= titanic['sex'] == 'female'

# %%
titanic = titanic.drop('sex', axis=1)

# %%
titanic.head()
# Out:
#    survived  pclass  age     fare female
# 0         0       3   22   7.2500  False
# 1         1       1   38  71.2833   True
# 2         1       3   26   7.9250   True
# 3         1       1   35  53.1000   True
# 4         0       3   35   8.0500  False

# %%
pd.scatter_matrix(titanic, figsize=(18, 18), s=100, alpha=0.1);

# %%
titanic.hist(figsize=(20, 9));

# %%
pd.crosstab(titanic.survived, titanic.female)
# Out:
# female    False  True
# survived
# 0           468     81
# 1           109    233

# %%
pd.crosstab(titanic.survived, titanic.pclass)
# Out:
# pclass      1   2    3
# survived
# 0          80  97  372
# 1         136  87  119

# %%
# Look for missing values:

len(titanic)
# Out:
# 891

# %%
titanic.isnull().sum()
# Out:
# survived      0
# pclass        0
# age         177
# fare          0
# female        0
# dtype: int64

# %%
len(titanic.dropna())
# Out:
# 714

# %%
data = titanic.dropna()

# %%
# Convert to numeric types
data = data.astype(np.int32)

# %%
titanic.age.hist(bins=20)

# %%
bins = np.linspace(0, 80, 20)

# %%
print bins
# Out:
# [  0.           4.21052632   8.42105263  12.63157895  16.84210526
#   21.05263158  25.26315789  29.47368421  33.68421053  37.89473684
#   42.10526316  46.31578947  50.52631579  54.73684211  58.94736842
#   63.15789474  67.36842105  71.57894737  75.78947368  80.        ]

# %%
age = data.age
female = data.female
survived = data.survived
