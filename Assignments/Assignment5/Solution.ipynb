# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
bikeshare_raw = pd.read_csv('../../Data/bikeshare.csv', header=0)

# %%
bikeshare = bikeshare_raw.drop(['instant'], axis=1)

# %%
pd.scatter_matrix(bikeshare, figsize = (20, 20));

# %%
bikeshare.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12973a8d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120c9be90>]], dtype=object)
